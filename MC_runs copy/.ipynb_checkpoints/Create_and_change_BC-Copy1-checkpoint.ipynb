# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import os
import shutil
import time
import h5py
import matplotlib.pyplot as plt

from subprocess import Popen

# %%
import matplotlib.animation as animation

# %%
loc = 'Run_1588876618'

# %% [markdown]
# ## Load Results

# %%
Ntsteps = 1800
Ninterfaces = 63
Nx = 64
Ny = Nx
Nr = 100
L = 1.
dx = L/Nx
dy = dx

k=np.zeros(Nx*Ny)
qcell = np.zeros((Ny,Ntsteps))
q = np.zeros((Nr,Ntsteps))

HMC = np.zeros((Nr+2,Nx,Ntsteps))

# %%
# loc = 'Run_1586995394'

# %%
f = open(f'./{loc}/6_months_run.hed')

hmc = np.loadtxt(f)

# %%
P = hmc.reshape((Ntsteps,64,64))

# %%
P.shape
# Out:
# (1800, 64, 64)

# %%
f = open('./../ADCME-diff/head_TF.csv')

hmc_tf = np.loadtxt(f)

P_tf = hmc_tf.reshape((64,64,Ntsteps))

# %%
# %matplotlib notebook

# %%
plt.imshow(P[0,:,:], cmap='hot', interpolation='nearest')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plt.clim(0, 0.5)

for tt in np.arange(0,1800,100):
#     print(int(tt))
    t = int(tt)
#     plt.imshow(P[t,:,:]-P_tf[:,:,t+1], cmap='hot', interpolation='nearest')
#     plt.colorbar()
#     plt.show()
    plt.imshow(P_tf[:,:,t], cmap='hot', interpolation='nearest')
    plt.clim(-0.1, 0.1)
    plt.colorbar()
#     plt.clim(0, 0.5)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b74aeb1cc0e2> in <module>
#       7 #     plt.colorbar()
#       8 #     plt.show()
# ----> 9     plt.imshow(P_tf[:,:,t], cmap='hot', interpolation='nearest')
#      10     plt.clim(-0.1, 0.1)
#      11     plt.colorbar()
#
# NameError: name 'P_tf' is not defined

# %%
for tt in np.arange(0,180,10):
#     print(int(tt))
    t = int(tt)
    plt.plot(P[t*10,0,:])
    plt.plot(P_tf[0,:,t*10+1])
#     plt.plot(Data_Specified_Head_values[0,:,t])

    plt.show()

# %%
P_tf[1,:,:]

# %%
P_tf[1,:,:]

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     160         try:
# --> 161             return self.avail[name]
#     162         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-ba3e39dc812e> in <module>
# ----> 1 Writer = animation.writers['ffmpeg']
#       2 writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     162         except KeyError:
#     163             raise RuntimeError(
# --> 164                 'Requested MovieWriter ({}) not available'.format(name))
#     165
#     166
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
