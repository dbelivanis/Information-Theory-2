# %%
import pandas as pd
import numpy as np
import math
from scipy import special
import matplotlib.pyplot as plt
import statsmodels.stats.weightstats as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-57231aaab898> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import math
#       4 from scipy import special
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
N_steps = 600
N_steps_orig = 1800 
N_k = 1
T_h = 18000
N_x = 21
N_y = 21

# %%
result_loc = "./"
train_loc = "Run_no_zero_flow_no_oscilations_Run_Run_1620834677/"

# %%
run_name = "loss_y_function_check_"
q_x = np.loadtxt(f"{result_loc}{run_name}flow_x.txt")
q_x = q_x.reshape([-1,N_k,N_steps])
q_y = np.loadtxt(f"{result_loc}{run_name}flow_y.txt")
q_y = q_y.reshape([-1,N_k,N_steps])
# k_x = np.loadtxt(f"{result_loc}{run_name}k_x.txt")
# k_x = k_x.reshape([-1,N_k,N_steps])
# k_y = np.loadtxt(f"{result_loc}{run_name}k_y.txt")
# k_y = k_y.reshape([-1,N_k,N_steps])
# k_xy = np.loadtxt(f"{result_loc}{run_name}k_xy.txt")
# k_xy = k_xy.reshape([-1,N_k,N_steps])
dw = np.loadtxt(f"{result_loc}{run_name}loss.txt")
dw = dw.reshape([-1,N_k])

# %%
plt.plot(q_y[0,0,:])
plt.plot(q_y[1,0,:])

# %%
q_MC_x = np.loadtxt(f"{train_loc}Q_x_5.txt")
q_MC_y = np.loadtxt(f"{train_loc}Q_y_5.txt")

# %%
plt.plot(q_MC_x.mean(axis=0))

for i in range(4):
    plt.plot(np.linspace(1,1800,N_steps),q_x[i*5,0,:])

# %%
plt.plot(q_MC_y.mean(axis=0))

for i in range(4):
    plt.plot(np.linspace(1,1800,N_steps),q_y[i*5,0,:])

# %%
dw
# Out:
# array([[1.05308840e+12],
#        [1.29878020e+12],
#        [1.59890145e+12],
#        [1.96516575e+12],
#        [2.41177489e+12],
#        [2.95594424e+12],
#        [3.61853866e+12],
#        [4.42484236e+12],
#        [5.40549074e+12],
#        [6.59759828e+12],
#        [8.04612370e+12],
#        [9.80552228e+12],
#        [1.19417457e+13],
#        [1.45346622e+13],
#        [1.76809860e+13],
#        [2.14978221e+13],
#        [2.61269566e+13],
#        [3.17400484e+13],
#        [3.85449124e+13],
#        [4.67931230e+13],
#        [5.67892156e+13]])

# %%
plt.plot(dw)

# %%
plt.plot(dw)
